# %%
import pandas as pd
import time
from GPcounts.GPcounts_Module import Fit_GPcounts
X = pd.read_csv('pseudoT_Index_1.csv',index_col=[0])
X_real = pd.read_csv('pst_real_1.csv',index_col=[0])
Y = pd.read_csv('Cyclic_Index_1.csv',index_col=[0])

# %%
genes_name =['H1239','H489','H1672']
gp_counts = Fit_GPcounts(X_real,Y.loc[genes_name])

# %%
likelihood = 'Negative_binomial' 
results = gp_counts.One_sample_test(likelihood)
display(results)
# Out:
# 100%|██████████| 3/3 [00:27<00:00,  9.05s/it]
#        Dynamic_model_log_likelihood  Constant_model_log_likelihood  \
# H1239                   -601.396739                    -601.752250
# H489                    -502.242083                    -502.242045
# H1672                   -523.438386                    -523.573784
#
#        log_likelihood_ratio
# H1239              0.355511
# H489              -0.000038
# H1672              0.135398

# %%
from helper import plot 
test_name = 'One_sample_test' 
params = gp_counts.load_predict_models(genes_name,test_name,likelihood)
plot(params,X_real.values,Y.loc[genes_name])
# Out:
# 100%|██████████| 3/3 [00:04<00:00,  1.54s/it]
# H1239
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.05680439522990732                                 </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>11.454706543313627                                  </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.1220841185194876                                  </td></tr>
# <tr><td>VGP.likelihood.scale   </td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-2.07162312e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[6.12872781e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>name                </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.06225562096733779                                 </td></tr>
# <tr><td>VGP.likelihood.alpha</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.1430949047655434                                  </td></tr>
# <tr><td>VGP.likelihood.scale</td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu            </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.48832715e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt          </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[3.15376552e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# H489
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.37126273604842175                                 </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>3850.492194488865                                   </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>1.8511961914724517                                  </td></tr>
# <tr><td>VGP.likelihood.scale   </td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.89860786e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[1.39280234e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>name                </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.37089708274364036                                 </td></tr>
# <tr><td>VGP.likelihood.alpha</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>1.8514009418579451                                  </td></tr>
# <tr><td>VGP.likelihood.scale</td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu            </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.90345480e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt          </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[1.39321381e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# H1672
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.2474983262663771                                  </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>33.16967803536785                                   </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.5429193655206492                                  </td></tr>
# <tr><td>VGP.likelihood.scale   </td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-7.06363174e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[3.23171227e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>name                </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.2516851558269367                                  </td></tr>
# <tr><td>VGP.likelihood.alpha</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.5594271711617416                                  </td></tr>
# <tr><td>VGP.likelihood.scale</td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu            </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.83693606e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt          </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[1.79875648e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>

# %%
genes_name =['H1239','H489','H1672']
gp_counts = Fit_GPcounts(X,Y.loc[genes_name])

# %%
likelihood = 'Negative_binomial' 
results = gp_counts.One_sample_test(likelihood)
display(results)
# Out:
# 100%|██████████| 3/3 [00:17<00:00,  5.92s/it]
#        Dynamic_model_log_likelihood  Constant_model_log_likelihood  \
# H1239                   -580.179377                    -601.752250
# H489                    -493.071479                    -502.242045
# H1672                   -506.779182                    -523.573784
#
#        log_likelihood_ratio
# H1239             21.572872
# H489               9.170566
# H1672             16.794602

# %%
from helper import plot 
test_name = 'One_sample_test' 
params = gp_counts.load_predict_models(genes_name,test_name,likelihood)
plot(params,X.values,Y.loc[genes_name])
# Out:
# 100%|██████████| 3/3 [00:04<00:00,  1.44s/it]
# H1239
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.6175240751175645                                  </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.730614444857904                                   </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>1.4700382852033487                                  </td></tr>
# <tr><td>VGP.likelihood.scale   </td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-2.33065762e+00...                                </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[3.68592444e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>name                </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.06223273111685801                                 </td></tr>
# <tr><td>VGP.likelihood.alpha</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.1430825156415505                                  </td></tr>
# <tr><td>VGP.likelihood.scale</td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu            </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.48943895e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt          </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[3.15438442e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# H489
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.7078668189098056                                  </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>3.2676434180536775                                  </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>1.404383860965039                                   </td></tr>
# <tr><td>VGP.likelihood.scale   </td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-1.88364223e+00...                                </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[3.01024214e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>name                </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.3709824849962468                                  </td></tr>
# <tr><td>VGP.likelihood.alpha</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>1.8513958032816613                                  </td></tr>
# <tr><td>VGP.likelihood.scale</td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu            </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.90256159e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt          </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[1.39322497e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# H1672
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.9711315742517774                                  </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>3.372689327598835                                   </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>1.791171916666315                                   </td></tr>
# <tr><td>VGP.likelihood.scale   </td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-2.08864341e+00...                                </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[2.98244800e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>name                </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.2517437090723833                                  </td></tr>
# <tr><td>VGP.likelihood.alpha</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>2.559392090329744                                   </td></tr>
# <tr><td>VGP.likelihood.scale</td><td>Parameter</td><td>              </td><td>       </td><td>False      </td><td>()           </td><td>float64</td><td>1.0                                                 </td></tr>
# <tr><td>VGP.q_mu            </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(505, 1)     </td><td>float64</td><td>[[-9.83534312e-01...                                </td></tr>
# <tr><td>VGP.q_sqrt          </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 505, 505)</td><td>float64</td><td>[[[1.79806987e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
