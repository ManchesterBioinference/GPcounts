# %% [markdown]
# Nuha BinTayyash, 2020
#
# This notebook shows the ROC and precision-recall curves resulted from running GPcounts with one sample test on simulated bulk RNA-seq datasets.

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import metrics
import pandas as pd
from scipy import stats

# %%
#DESeq2 = pd.read_csv('fission_DESeq2_tst_scaled.csv',index_col=[0])
#print(DESeq2.shape)
GPcounts_NB = pd.read_csv('ll_Negative_binomial_exons_counts.csv',index_col=[0])
GPcounts_G = pd.read_csv('ll_Gaussian_exons_counts.csv',index_col=[0])
print(GPcounts_NB.shape)
print(GPcounts_G.shape)
# Out:
# (8217, 3)
# (8217, 3)

# %%
#DESeq_sorted = DESeq2.sort_values(by=['pvalue'])
#DESeq_sorted

# %%
GPcounts_NB_sorted = GPcounts_NB.sort_values(by=['log_likelihood_ratio'], ascending=False)
GPcounts_NB_sorted
# Out:
#              Dynamic_model_log_likelihood  Constant_model_log_likelihood  \
# FBgn0038028                   -149.324493                   -2037.260557
# FBgn0026361                   -157.812399                   -1850.014347
# FBgn0259734                   -126.509842                   -1808.848183
# FBgn0038071                   -153.307992                   -1777.087497
# FBgn0021776                   -146.230436                   -1734.875164
# ...                                   ...                            ...
# FBgn0037020                   -111.813599                    -101.905812
# FBgn0031315                    -50.455017                     -33.863043
# FBgn0037263                   2505.705132                    2523.142765
# FBgn0032420                  19909.121840                   19929.400001
# FBgn0031398                   -170.363623                    -147.416169
#
#              log_likelihood_ratio
# FBgn0038028           1887.936064
# FBgn0026361           1692.201949
# FBgn0259734           1682.338340
# FBgn0038071           1623.779505
# FBgn0021776           1588.644728
# ...                           ...
# FBgn0037020             -9.907787
# FBgn0031315            -16.591974
# FBgn0037263            -17.437633
# FBgn0032420            -20.278161
# FBgn0031398            -22.947455
#
# [8217 rows x 3 columns]

# %% [markdown]
# True Positives - dynamic genes

# %%
D = GPcounts_NB.shape[0]
true_label = np.zeros(D)
for j in range(D):
    if GPcounts_NB['log_likelihood_ratio'][j] > 0:
        true_label[j] = 1
labels = pd.DataFrame(true_label, index =GPcounts_NB.index.values, columns =['label'])
GPcounts_NB = pd.concat([GPcounts_NB,labels],axis = 1)

# %%
TP_genes_NB = list(GPcounts_NB.loc[(GPcounts_NB['log_likelihood_ratio'] > 0)&(GPcounts_NB['label']==1.0)].index.values)
len(TP_genes_NB)
# Out:
# 7355

# %%
TP_genes_G = list(GPcounts_G.loc[(GPcounts_G['log_likelihood_ratio'] > 0)&(GPcounts_NB['label']==1.0)].index.values)
len(TP_genes_G)
# Out:
# 7229

# %%
FP_genes_G = list(GPcounts_G.loc[(GPcounts_G['log_likelihood_ratio'] < 0)&(GPcounts_NB['label']==1.0)].index.values)
len(FP_genes_G)
# Out:
# 120

# %%
FP_genes_G
# Out:
# ['FBgn0000045',
#  'FBgn0002773',
#  'FBgn0003638',
#  'FBgn0003888',
#  'FBgn0004237',
#  'FBgn0010226',
#  'FBgn0010504',
#  'FBgn0011888',
#  'FBgn0011944',
#  'FBgn0011994',
#  'FBgn0013679',
#  'FBgn0013681',
#  'FBgn0013684',
#  'FBgn0013812',
#  'FBgn0015791',
#  'FBgn0020307',
#  'FBgn0022710',
#  'FBgn0023531',
#  'FBgn0024232',
#  'FBgn0026175',
#  'FBgn0027494',
#  'FBgn0027600',
#  'FBgn0028979',
#  'FBgn0029133',
#  'FBgn0029512',
#  'FBgn0029524',
#  'FBgn0029769',
#  'FBgn0030945',
#  'FBgn0031343',
#  'FBgn0031418',
#  'FBgn0031811',
#  'FBgn0031937',
#  'FBgn0032224',
#  'FBgn0032382',
#  'FBgn0032516',
#  'FBgn0032986',
#  'FBgn0033207',
#  'FBgn0033247',
#  'FBgn0033354',
#  'FBgn0033387',
#  'FBgn0033802',
#  'FBgn0033875',
#  'FBgn0033982',
#  'FBgn0034247',
#  'FBgn0034578',
#  'FBgn0034837',
#  'FBgn0034839',
#  'FBgn0035088',
#  'FBgn0035189',
#  'FBgn0035917',
#  'FBgn0035968',
#  'FBgn0037721',
#  'FBgn0038095',
#  'FBgn0038237',
#  'FBgn0038307',
#  'FBgn0038771',
#  'FBgn0038852',
#  'FBgn0039006',
#  'FBgn0039120',
#  'FBgn0039124',
#  'FBgn0039722',
#  'FBgn0039927',
#  'FBgn0040793',
#  'FBgn0043841',
#  'FBgn0050046',
#  'FBgn0050286',
#  'FBgn0050359',
#  'FBgn0050398',
#  'FBgn0050447',
#  'FBgn0051041',
#  'FBgn0051165',
#  'FBgn0051242',
#  'FBgn0051481',
#  'FBgn0052017',
#  'FBgn0052311',
#  'FBgn0052814',
#  'FBgn0053217',
#  'FBgn0053363',
#  'FBgn0053519',
#  'FBgn0054031',
#  'FBgn0058178',
#  'FBgn0063384',
#  'FBgn0065053',
#  'FBgn0065073',
#  'FBgn0082929',
#  'FBgn0082988',
#  'FBgn0083006',
#  'FBgn0083017',
#  'FBgn0083028',
#  'FBgn0085413',
#  'FBgn0085419',
#  'FBgn0085443',
#  'FBgn0085771',
#  'FBgn0085813',
#  'FBgn0259822',
#  'FBgn0259992',
#  'FBgn0260027',
#  'FBgn0260458',
#  'FBgn0262117',
#  'FBgn0262366',
#  'FBgn0262952',
#  'FBgn0263538',
#  'FBgn0263829',
#  'FBgn0264372',
#  'FBgn0264695',
#  'FBgn0264711',
#  'FBgn0264894',
#  'FBgn0266042',
#  'FBgn0266903',
#  'FBgn0267279',
#  'FBgn0267326',
#  'FBgn0267511',
#  'FBgn0267515',
#  'FBgn0267519',
#  'FBgn0267560',
#  'FBgn0267726',
#  'FBgn0283427',
#  'FBgn0283508',
#  'FBgn0283545',
#  'FBgn0284250']

# %%
GPcounts_NB.loc[FP_genes_G]
# Out:
#              Dynamic_model_log_likelihood  Constant_model_log_likelihood  \
# FBgn0000045                    -19.525716                     -19.525718
# FBgn0002773                    -35.618721                     -38.758827
# FBgn0003638                   -116.412495                    -116.744468
# FBgn0003888                    -11.280226                     -16.909235
# FBgn0004237                   -151.623734                    -152.010106
# ...                                   ...                            ...
# FBgn0267726                    -18.740767                     -23.767638
# FBgn0283427                    -99.450389                    -100.462709
# FBgn0283508                    -10.214612                     -15.079527
# FBgn0283545                    -20.380790                     -21.128208
# FBgn0284250                    -10.996777                     -16.447932
#
#              log_likelihood_ratio  label
# FBgn0000045              0.000001    1.0
# FBgn0002773              3.140106    1.0
# FBgn0003638              0.331973    1.0
# FBgn0003888              5.629009    1.0
# FBgn0004237              0.386371    1.0
# ...                           ...    ...
# FBgn0267726              5.026871    1.0
# FBgn0283427              1.012319    1.0
# FBgn0283508              4.864915    1.0
# FBgn0283545              0.747418    1.0
# FBgn0284250              5.451155    1.0
#
# [120 rows x 4 columns]

# %%
GPcounts_G.loc[FP_genes_G]
# Out:
#              Dynamic_model_log_likelihood  Constant_model_log_likelihood  \
# FBgn0000045                    -28.645940                     -28.164254
# FBgn0002773                    -33.989792                     -31.464809
# FBgn0003638                      1.230064                       1.230142
# FBgn0003888                    -15.093584                     -15.025439
# FBgn0004237                     -6.213963                      -6.213929
# ...                                   ...                            ...
# FBgn0267726                    -21.445705                     -20.833522
# FBgn0283427                    -30.194308                     -30.194038
# FBgn0283508                     -8.378991                      -8.284142
# FBgn0283545                    -12.677149                     -10.422715
# FBgn0284250                    -13.313928                     -13.239297
#
#              log_likelihood_ratio
# FBgn0000045             -0.481687
# FBgn0002773             -2.524983
# FBgn0003638             -0.000078
# FBgn0003888             -0.068145
# FBgn0004237             -0.000034
# ...                           ...
# FBgn0267726             -0.612183
# FBgn0283427             -0.000269
# FBgn0283508             -0.094848
# FBgn0283545             -2.254434
# FBgn0284250             -0.074632
#
# [120 rows x 3 columns]

# %%
Yuliyas_genes = pd.read_csv('genes_unnormalized.csv',index_col=[0])
Yuliyas_genes
# Out:
# Empty DataFrame
# Columns: []
# Index: [FBgn0000008, FBgn0000117, FBgn0000119, FBgn0000157, FBgn0000163, FBgn0000180, FBgn0000259, FBgn0000283, FBgn0000320, FBgn0000395, FBgn0000404, FBgn0000439, FBgn0000459, FBgn0000463, FBgn0000490, FBgn0000542, FBgn0000575, FBgn0000578, FBgn0000711, FBgn0000719, FBgn0000723, FBgn0001090, FBgn0001123, FBgn0001128, FBgn0001168, FBgn0001197, FBgn0001235, FBgn0001323, FBgn0001404, FBgn0001624, FBgn0002121, FBgn0002306, FBgn0002524, FBgn0002543, FBgn0002873, FBgn0002921, FBgn0002931, FBgn0002932, FBgn0002945, FBgn0003002, FBgn0003028, FBgn0003041, FBgn0003205, FBgn0003209, FBgn0003227, FBgn0003254, FBgn0003308, FBgn0003328, FBgn0003391, FBgn0003396, FBgn0003660, FBgn0003892, FBgn0003896, FBgn0003984, FBgn0004101, FBgn0004102, FBgn0004107, FBgn0004108, FBgn0004387, FBgn0004449, FBgn0004456, FBgn0004569, FBgn0004583, FBgn0004595, FBgn0004635, FBgn0004638, FBgn0004646, FBgn0004795, FBgn0004837, FBgn0004839, FBgn0004859, FBgn0004860, FBgn0004861, FBgn0004868, FBgn0004885, FBgn0004893, FBgn0005427, FBgn0005536, FBgn0005612, FBgn0005672, FBgn0005695, FBgn0008636, FBgn0010105, FBgn0010228, FBgn0010238, FBgn0010269, FBgn0010280, FBgn0010300, FBgn0010303, FBgn0010323, FBgn0010379, FBgn0010415, FBgn0010473, FBgn0010651, FBgn0011202, FBgn0011204, FBgn0011207, FBgn0011211, FBgn0011225, FBgn0011236, ...]
#
# [523 rows x 0 columns]

# %%
best  = set(TP_genes_NB).intersection(Yuliyas_genes.index.values)
len(list(best))
# Out:
# 523

# %%
best  = set(TP_genes_G).intersection(Yuliyas_genes.index.values)
len(list(best))
# Out:
# 523

# %% [markdown]
# True Negatives- Constant genes

# %%
TN_genes_NB = list(GPcounts_NB.loc[(GPcounts_NB['log_likelihood_ratio'] < 0)&(GPcounts_NB['label']==0.0)].index.values)
len(TN_genes_NB)
# Out:
# 862

# %%
TN_genes_G = list(GPcounts_G.loc[(GPcounts_G['log_likelihood_ratio'] < 0)&(GPcounts_NB['label']==0.0)].index.values)
len(TN_genes_G)
# Out:
# 246

# %%
FN_genes_G = list(GPcounts_G.loc[(GPcounts_G['log_likelihood_ratio'] > 0)&(GPcounts_NB['label']==0.0)].index.values)
len(FN_genes_G)
# Out:
# 616

# %%
FN_genes_G
# Out:
# ['FBgn0000047',
#  'FBgn0000083',
#  'FBgn0000108',
#  'FBgn0000109',
#  'FBgn0000115',
#  'FBgn0000221',
#  'FBgn0000274',
#  'FBgn0000289',
#  'FBgn0000318',
#  'FBgn0000464',
#  'FBgn0000618',
#  'FBgn0001099',
#  'FBgn0001202',
#  'FBgn0001276',
#  'FBgn0001977',
#  'FBgn0001995',
#  'FBgn0003189',
#  'FBgn0003499',
#  'FBgn0003517',
#  'FBgn0003520',
#  'FBgn0003916',
#  'FBgn0003923',
#  'FBgn0004132',
#  'FBgn0004185',
#  'FBgn0004647',
#  'FBgn0004908',
#  'FBgn0005558',
#  'FBgn0005775',
#  'FBgn0010078',
#  'FBgn0010114',
#  'FBgn0010287',
#  'FBgn0010395',
#  'FBgn0010409',
#  'FBgn0010470',
#  'FBgn0010622',
#  'FBgn0011227',
#  'FBgn0011335',
#  'FBgn0011455',
#  'FBgn0011476',
#  'FBgn0011570',
#  'FBgn0011762',
#  'FBgn0013305',
#  'FBgn0013432',
#  'FBgn0013672',
#  'FBgn0013674',
#  'FBgn0013683',
#  'FBgn0014022',
#  'FBgn0014092',
#  'FBgn0015036',
#  'FBgn0015298',
#  'FBgn0015575',
#  'FBgn0015925',
#  'FBgn0016978',
#  'FBgn0017430',
#  'FBgn0017567',
#  'FBgn0019985',
#  'FBgn0020270',
#  'FBgn0020305',
#  'FBgn0020370',
#  'FBgn0020372',
#  'FBgn0020909',
#  'FBgn0020930',
#  'FBgn0021818',
#  'FBgn0021856',
#  'FBgn0022224',
#  'FBgn0022943',
#  'FBgn0023023',
#  'FBgn0023170',
#  'FBgn0023171',
#  'FBgn0023213',
#  'FBgn0023519',
#  'FBgn0024366',
#  'FBgn0024945',
#  'FBgn0024984',
#  'FBgn0024987',
#  'FBgn0025387',
#  'FBgn0025519',
#  'FBgn0025558',
#  'FBgn0025640',
#  'FBgn0025724',
#  'FBgn0026090',
#  'FBgn0026169',
#  'FBgn0026181',
#  'FBgn0026199',
#  'FBgn0026378',
#  'FBgn0026401',
#  'FBgn0026722',
#  'FBgn0027083',
#  'FBgn0027259',
#  'FBgn0027341',
#  'FBgn0027524',
#  'FBgn0027864',
#  'FBgn0028424',
#  'FBgn0028499',
#  'FBgn0028645',
#  'FBgn0028664',
#  'FBgn0028707',
#  'FBgn0028919',
#  'FBgn0028956',
#  'FBgn0028990',
#  'FBgn0029529',
#  'FBgn0029588',
#  'FBgn0029710',
#  'FBgn0029778',
#  'FBgn0029821',
#  'FBgn0029833',
#  'FBgn0029868',
#  'FBgn0030006',
#  'FBgn0030017',
#  'FBgn0030120',
#  'FBgn0030177',
#  'FBgn0030270',
#  'FBgn0030291',
#  'FBgn0030292',
#  'FBgn0030347',
#  'FBgn0030351',
#  'FBgn0030373',
#  'FBgn0030433',
#  'FBgn0030485',
#  'FBgn0030518',
#  'FBgn0030571',
#  'FBgn0030583',
#  'FBgn0030605',
#  'FBgn0030611',
#  'FBgn0030628',
#  'FBgn0030653',
#  'FBgn0030657',
#  'FBgn0030668',
#  'FBgn0030673',
#  'FBgn0030711',
#  'FBgn0030718',
#  'FBgn0030801',
#  'FBgn0030813',
#  'FBgn0030851',
#  'FBgn0031008',
#  'FBgn0031047',
#  'FBgn0031057',
#  'FBgn0031070',
#  'FBgn0031157',
#  'FBgn0031171',
#  'FBgn0031256',
#  'FBgn0031270',
#  'FBgn0031309',
#  'FBgn0031310',
#  'FBgn0031313',
#  'FBgn0031315',
#  'FBgn0031357',
#  'FBgn0031361',
#  'FBgn0031391',
#  'FBgn0031398',
#  'FBgn0031419',
#  'FBgn0031459',
#  'FBgn0031485',
#  'FBgn0031505',
#  'FBgn0031529',
#  'FBgn0031609',
#  'FBgn0031663',
#  'FBgn0031678',
#  'FBgn0031683',
#  'FBgn0031684',
#  'FBgn0031689',
#  'FBgn0031766',
#  'FBgn0031774',
#  'FBgn0031821',
#  'FBgn0031832',
#  'FBgn0031881',
#  'FBgn0031909',
#  'FBgn0031972',
#  'FBgn0032000',
#  'FBgn0032034',
#  'FBgn0032053',
#  'FBgn0032054',
#  'FBgn0032101',
#  'FBgn0032149',
#  'FBgn0032153',
#  'FBgn0032166',
#  'FBgn0032228',
#  'FBgn0032343',
#  'FBgn0032398',
#  'FBgn0032399',
#  'FBgn0032407',
#  'FBgn0032420',
#  'FBgn0032421',
#  'FBgn0032452',
#  'FBgn0032476',
#  'FBgn0032524',
#  'FBgn0032703',
#  'FBgn0032720',
#  'FBgn0032727',
#  'FBgn0032730',
#  'FBgn0032785',
#  'FBgn0032811',
#  'FBgn0032812',
#  'FBgn0032818',
#  'FBgn0032833',
#  'FBgn0032846',
#  'FBgn0032849',
#  'FBgn0032921',
#  'FBgn0032922',
#  'FBgn0033033',
#  'FBgn0033060',
#  'FBgn0033079',
#  'FBgn0033085',
#  'FBgn0033100',
#  'FBgn0033104',
#  'FBgn0033184',
#  'FBgn0033208',
#  'FBgn0033340',
#  'FBgn0033341',
#  'FBgn0033350',
#  'FBgn0033356',
#  'FBgn0033357',
#  'FBgn0033429',
#  'FBgn0033431',
#  'FBgn0033434',
#  'FBgn0033480',
#  'FBgn0033491',
#  'FBgn0033523',
#  'FBgn0033529',
#  'FBgn0033543',
#  'FBgn0033548',
#  'FBgn0033550',
#  'FBgn0033605',
#  'FBgn0033691',
#  'FBgn0033712',
#  'FBgn0033769',
#  'FBgn0033891',
#  'FBgn0033905',
#  'FBgn0033934',
#  'FBgn0033948',
#  'FBgn0033961',
#  'FBgn0033972',
#  'FBgn0033978',
#  'FBgn0034001',
#  'FBgn0034033',
#  'FBgn0034057',
#  'FBgn0034086',
#  'FBgn0034093',
#  'FBgn0034117',
#  'FBgn0034157',
#  'FBgn0034177',
#  'FBgn0034179',
#  'FBgn0034217',
#  'FBgn0034219',
#  'FBgn0034242',
#  'FBgn0034243',
#  'FBgn0034321',
#  'FBgn0034322',
#  'FBgn0034361',
#  'FBgn0034402',
#  'FBgn0034422',
#  'FBgn0034430',
#  'FBgn0034436',
#  'FBgn0034523',
#  'FBgn0034599',
#  'FBgn0034645',
#  'FBgn0034748',
#  'FBgn0034800',
#  'FBgn0034814',
#  'FBgn0034846',
#  'FBgn0034877',
#  'FBgn0034902',
#  'FBgn0034908',
#  'FBgn0034923',
#  'FBgn0034986',
#  'FBgn0035020',
#  'FBgn0035063',
#  'FBgn0035082',
#  'FBgn0035109',
#  'FBgn0035132',
#  'FBgn0035140',
#  'FBgn0035179',
#  'FBgn0035210',
#  'FBgn0035254',
#  'FBgn0035318',
#  'FBgn0035323',
#  'FBgn0035333',
#  'FBgn0035335',
#  'FBgn0035393',
#  'FBgn0035401',
#  'FBgn0035410',
#  'FBgn0035469',
#  'FBgn0035484',
#  'FBgn0035515',
#  'FBgn0035520',
#  'FBgn0035534',
#  'FBgn0035574',
#  'FBgn0035590',
#  'FBgn0035624',
#  'FBgn0035675',
#  'FBgn0035715',
#  'FBgn0035721',
#  'FBgn0035726',
#  'FBgn0035770',
#  'FBgn0035805',
#  'FBgn0035831',
#  'FBgn0035852',
#  'FBgn0035868',
#  'FBgn0035876',
#  'FBgn0035960',
#  'FBgn0035980',
#  'FBgn0035996',
#  'FBgn0036036',
#  'FBgn0036062',
#  'FBgn0036118',
#  'FBgn0036121',
#  'FBgn0036192',
#  'FBgn0036266',
#  'FBgn0036277',
#  'FBgn0036318',
#  'FBgn0036381',
#  'FBgn0036406',
#  'FBgn0036423',
#  'FBgn0036666',
#  'FBgn0036696',
#  'FBgn0036745',
#  'FBgn0036804',
#  'FBgn0036818',
#  'FBgn0036826',
#  'FBgn0036848',
#  'FBgn0036959',
#  'FBgn0036998',
#  'FBgn0037009',
#  'FBgn0037020',
#  'FBgn0037028',
#  'FBgn0037121',
#  'FBgn0037232',
#  'FBgn0037263',
#  'FBgn0037330',
#  'FBgn0037342',
#  'FBgn0037350',
#  'FBgn0037351',
#  'FBgn0037377',
#  'FBgn0037440',
#  'FBgn0037446',
#  'FBgn0037478',
#  'FBgn0037525',
#  'FBgn0037529',
#  'FBgn0037543',
#  'FBgn0037578',
#  'FBgn0037602',
#  'FBgn0037608',
#  'FBgn0037611',
#  'FBgn0037636',
#  'FBgn0037648',
#  'FBgn0037654',
#  'FBgn0037683',
#  'FBgn0037708',
#  'FBgn0037713',
#  'FBgn0037743',
#  'FBgn0037749',
#  'FBgn0037773',
#  'FBgn0037877',
#  'FBgn0037883',
#  'FBgn0037898',
#  'FBgn0037912',
#  'FBgn0037972',
#  'FBgn0037973',
#  'FBgn0038233',
#  'FBgn0038234',
#  'FBgn0038275',
#  'FBgn0038279',
#  'FBgn0038301',
#  'FBgn0038302',
#  'FBgn0038321',
#  'FBgn0038324',
#  'FBgn0038455',
#  'FBgn0038471',
#  'FBgn0038474',
#  'FBgn0038519',
#  'FBgn0038536',
#  'FBgn0038545',
#  'FBgn0038576',
#  'FBgn0038583',
#  'FBgn0038627',
#  'FBgn0038673',
#  'FBgn0038678',
#  'FBgn0038735',
#  'FBgn0038766',
#  'FBgn0038804',
#  'FBgn0038811',
#  'FBgn0038868',
#  'FBgn0038923',
#  'FBgn0039020',
#  'FBgn0039025',
#  'FBgn0039129',
#  'FBgn0039137',
#  'FBgn0039165',
#  'FBgn0039214',
#  'FBgn0039215',
#  'FBgn0039259',
#  'FBgn0039355',
#  'FBgn0039427',
#  'FBgn0039564',
#  'FBgn0039639',
#  'FBgn0039650',
#  'FBgn0039765',
#  'FBgn0039862',
#  'FBgn0039881',
#  'FBgn0039883',
#  'FBgn0039930',
#  'FBgn0039938',
#  'FBgn0040007',
#  'FBgn0040031',
#  'FBgn0040227',
#  'FBgn0040228',
#  'FBgn0040323',
#  'FBgn0040339',
#  'FBgn0040351',
#  'FBgn0040373',
#  'FBgn0040534',
#  'FBgn0040575',
#  'FBgn0040666',
#  'FBgn0040754',
#  'FBgn0040786',
#  'FBgn0040907',
#  'FBgn0040929',
#  'FBgn0040931',
#  'FBgn0040964',
#  'FBgn0041004',
#  'FBgn0041588',
#  'FBgn0041720',
#  'FBgn0041723',
#  'FBgn0042085',
#  'FBgn0042112',
#  'FBgn0042127',
#  'FBgn0043799',
#  'FBgn0044020',
#  'FBgn0044047',
#  'FBgn0044511',
#  'FBgn0047038',
#  'FBgn0047114',
#  'FBgn0050000',
#  'FBgn0050001',
#  'FBgn0050022',
#  'FBgn0050047',
#  'FBgn0050077',
#  'FBgn0050094',
#  'FBgn0050105',
#  'FBgn0050157',
#  'FBgn0050390',
#  'FBgn0050423',
#  'FBgn0050476',
#  'FBgn0050496',
#  'FBgn0051021',
#  'FBgn0051053',
#  'FBgn0051098',
#  'FBgn0051159',
#  'FBgn0051195',
#  'FBgn0051216',
#  'FBgn0051229',
#  'FBgn0051279',
#  'FBgn0051320',
#  'FBgn0051373',
#  'FBgn0051390',
#  'FBgn0051441',
#  'FBgn0051453',
#  'FBgn0051522',
#  'FBgn0051673',
#  'FBgn0051712',
#  'FBgn0051713',
#  'FBgn0051717',
#  'FBgn0051807',
#  'FBgn0051849',
#  'FBgn0051864',
#  'FBgn0051866',
#  'FBgn0051897',
#  'FBgn0051908',
#  'FBgn0051950',
#  'FBgn0052069',
#  'FBgn0052099',
#  'FBgn0052115',
#  'FBgn0052133',
#  'FBgn0052163',
#  'FBgn0052278',
#  'FBgn0052281',
#  'FBgn0052418',
#  'FBgn0052448',
#  'FBgn0052554',
#  'FBgn0052576',
#  'FBgn0052590',
#  'FBgn0052708',
#  'FBgn0052773',
#  'FBgn0053002',
#  'FBgn0053054',
#  'FBgn0053096',
#  'FBgn0053107',
#  'FBgn0053276',
#  'FBgn0053319',
#  'FBgn0054008',
#  'FBgn0054015',
#  'FBgn0058470',
#  'FBgn0060292',
#  'FBgn0061492',
#  'FBgn0062440',
#  'FBgn0065035',
#  'FBgn0065047',
#  'FBgn0065048',
#  'FBgn0065051',
#  'FBgn0065057',
#  'FBgn0067629',
#  'FBgn0069242',
#  'FBgn0083038',
#  'FBgn0083953',
#  'FBgn0083961',
#  'FBgn0083970',
#  'FBgn0083983',
#  'FBgn0083984',
#  'FBgn0085192',
#  'FBgn0085203',
#  'FBgn0085229',
#  'FBgn0085242',
#  'FBgn0085257',
#  'FBgn0085271',
#  'FBgn0085284',
#  'FBgn0085290',
#  'FBgn0085352',
#  'FBgn0085405',
#  'FBgn0085433',
#  'FBgn0085446',
#  'FBgn0085453',
#  'FBgn0085732',
#  'FBgn0086074',
#  'FBgn0086446',
#  'FBgn0086447',
#  'FBgn0086662',
#  'FBgn0086663',
#  'FBgn0086672',
#  'FBgn0086704',
#  'FBgn0250868',
#  'FBgn0259112',
#  'FBgn0259176',
#  'FBgn0259242',
#  'FBgn0259916',
#  'FBgn0259982',
#  'FBgn0259986',
#  'FBgn0260444',
#  'FBgn0260859',
#  'FBgn0260860',
#  'FBgn0260861',
#  'FBgn0260933',
#  'FBgn0261266',
#  'FBgn0261452',
#  'FBgn0261453',
#  'FBgn0261549',
#  'FBgn0261562',
#  'FBgn0261671',
#  'FBgn0261976',
#  'FBgn0262524',
#  'FBgn0262887',
#  'FBgn0262902',
#  'FBgn0262954',
#  'FBgn0262962',
#  'FBgn0262987',
#  'FBgn0263001',
#  'FBgn0263018',
#  'FBgn0263047',
#  'FBgn0263414',
#  'FBgn0263475',
#  'FBgn0263479',
#  'FBgn0263480',
#  'FBgn0263484',
#  'FBgn0263507',
#  'FBgn0263606',
#  'FBgn0263607',
#  'FBgn0263659',
#  'FBgn0263660',
#  'FBgn0263772',
#  'FBgn0263831',
#  'FBgn0263847',
#  'FBgn0263863',
#  'FBgn0264439',
#  'FBgn0264504',
#  'FBgn0264602',
#  'FBgn0264703',
#  'FBgn0264721',
#  'FBgn0264751',
#  'FBgn0264863',
#  'FBgn0264945',
#  'FBgn0264957',
#  'FBgn0265047',
#  'FBgn0265177',
#  'FBgn0265184',
#  'FBgn0265318',
#  'FBgn0265351',
#  'FBgn0265487',
#  'FBgn0265533',
#  'FBgn0265705',
#  'FBgn0265902',
#  'FBgn0265937',
#  'FBgn0265987',
#  'FBgn0266005',
#  'FBgn0266019',
#  'FBgn0266396',
#  'FBgn0266457',
#  'FBgn0266518',
#  'FBgn0266645',
#  'FBgn0266681',
#  'FBgn0266699',
#  'FBgn0266711',
#  'FBgn0266722',
#  'FBgn0266724',
#  'FBgn0266752',
#  'FBgn0266917',
#  'FBgn0267041',
#  'FBgn0267525',
#  'FBgn0267545',
#  'FBgn0267733',
#  'FBgn0267808',
#  'FBgn0270927',
#  'FBgn0283440',
#  'FBgn0283525',
#  'FBgn0283652',
#  'FBgn0283666',
#  'FBgn0285879',
#  'FBgn0285949']

# %%
best  = set(TP_genes_NB).intersection(TP_genes_G)
len(list(best))
# Out:
# 7229

# %%
NB_plus = list(GPcounts_G.loc[(GPcounts_G['log_likelihood_ratio'] > 0)].index.values)

# %%
NB_minus = list(GPcounts_G.loc[(GPcounts_G['log_likelihood_ratio'] < 0)].index.values)

# %%
G_plus = list(GPcounts_G.loc[(GPcounts_NB['log_likelihood_ratio'] > 0)].index.values)

# %%
G_minus = list(GPcounts_G.loc[(GPcounts_NB['log_likelihood_ratio'] < 0)].index.values)

# %%
best  = set(NB_plus).intersection(G_plus)
len(list(best))
# Out:
# 7229

# %%
best  = set(NB_plus).intersection(G_minus)
len(list(best))
# Out:
# 616

# %%
best  = set(NB_minus).intersection(G_plus)
len(list(best))
# Out:
# 120

# %%
best  = set(NB_minus).intersection(G_minus)
len(list(best))
# Out:
# 246

# %% [markdown]
# NB + GP + --> 7229
# NB + GP -  --> 616
# NB - GP + --> 120
# NB - GP - -->  246

# %% [markdown]
# Introns

# %%
GPcounts_NB_in = pd.read_csv('ll_Negative_binomial_introns_counts.csv',index_col=[0])
GPcounts_G_in = pd.read_csv('ll_Gaussian_introns_counts.csv',index_col=[0])

# %%
GPcounts_NB_in.sort_values(by=['log_likelihood_ratio'], ascending=False)

# %%
D = GPcounts_NB_in.shape[0]
true_label = np.zeros(D)
for j in range(D):
    if GPcounts_NB_in['log_likelihood_ratio'][j] > 0:
        true_label[j] = 1
labels = pd.DataFrame(true_label, index =GPcounts_NB_in.index.values, columns =['label'])
GPcounts_NB_in = pd.concat([GPcounts_NB_in,labels],axis = 1)

# %%
TP_genes_NB_in = list(GPcounts_NB_in.loc[(GPcounts_NB_in['log_likelihood_ratio'] > 0)&(GPcounts_NB_in['label']==1.0)].index.values)
len(TP_genes_NB_in)

# %%
best  = set(TP_genes_NB).intersection(TP_genes_NB_in)
len(list(best))

# %%
TP_genes_G_in = list(GPcounts_G_in.loc[(GPcounts_G_in['log_likelihood_ratio'] > 0)&(GPcounts_NB_in['label']==1.0)].index.values)
len(TP_genes_G_in)

# %%
best  = set(TP_genes_G).intersection(TP_genes_G_in)
len(list(best))
