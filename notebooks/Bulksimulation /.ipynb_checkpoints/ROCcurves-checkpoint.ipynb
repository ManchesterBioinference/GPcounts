# %% [markdown]
# # ROC and precision-recall curves

# %% [markdown]
# Nuha BinTayyash, 2020
#
# This notebook shows the ROC and precision-recall curves resulted from running GPcounts with one sample test on simulated bulk RNA-seq datasets.

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import metrics
import pandas as pd

# %%
filesname = ['low_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv'
            ,'low_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv'                                     
            ,'high_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv'
            ,'high_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv']
            
for file in filesname:
    print(file)
    
    Gaussian = pd.read_csv('ll_ratio_Gaussian_'+file,index_col=[0])
    NegativeBinomial = pd.read_csv('ll_ratio_Negative_binomial_'+file,index_col=[0])
    Poisson = pd.read_csv('ll_ratio_Poisson_'+file,index_col=[0])
    
    D = NegativeBinomial.shape[0]
    true_label = np.zeros(D)
    
    for j in range(D):
        if j %2 == 0:
            true_label[j] = 1

    labels = pd.DataFrame(true_label, index =NegativeBinomial.index.values, columns =['label'])
    NegativeBinomial = pd.concat([NegativeBinomial,labels],axis = 1)

    fig = plt.figure()
    
    plt.tick_params(labelsize='large', width=2)     
    fpr_NB, tpr_NB, thresholds_NB = metrics.roc_curve( NegativeBinomial['label'], NegativeBinomial['log_likelihood_ratio'])
    AUC_NB=metrics.auc(fpr_NB, tpr_NB)
    plt.plot(fpr_NB, tpr_NB,color='green',label='GPcounts with Negative binomail likelihood {0:.4f}'.format(AUC_NB))
    
    
    fpr_G, tpr_G, thresholds_G = metrics.roc_curve(NegativeBinomial['label'],Gaussian['log_likelihood_ratio'])
    AUC_G=metrics.auc(fpr_G, tpr_G)
    plt.plot(fpr_G, tpr_G, color='darkorange', label='GPcounts with Gaussian likelihood {0:.4f}'.format(AUC_G))
    
    
    fpr_P, tpr_P, thresholds_P = metrics.roc_curve( NegativeBinomial['label'], Poisson['log_likelihood_ratio'])
    AUC_P=metrics.auc(fpr_P, tpr_P)
    plt.plot(fpr_P, tpr_P,color='blue',label='GPcounts with Poisson likelihood {0:.4f}'.format(AUC_P))
    
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    '''
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    
    plt.subplot(1, 2, 2)
    
    precision_NB, recall_NB, thresholds_NB = metrics.precision_recall_curve( NegativeBinomial['label'], NegativeBinomial['log_likelihood_ratio'])
    plt.plot( recall_NB,precision_NB,color='green',label='GPcounts with Negative binomail likelihood')
    
    precision_G, recall_G, thresholds_G = metrics.precision_recall_curve(NegativeBinomial['label'],Gaussian['log_likelihood_ratio'])
    plt.plot(recall_G, precision_G, color='darkorange', label='GPcounts with Gaussian ll')
    
    precision_P, recall_P, thresholds_P = metrics.precision_recall_curve( NegativeBinomial['label'], Poisson['log_likelihood_ratio'])
    plt.plot( recall_P,precision_P,color='blue',label='GPcounts with Poisson ll')
    
    plt.xlabel('recall')
    plt.ylabel('precision')
    '''
    plt.legend(loc='upper center', bbox_to_anchor=(.56, 0.25))
    plt.show()
    
    print('AUC for GPcounts with Negative Binomial likelihood',AUC_NB)
    print('AUC for GPcounts with Gaussian likelihood',AUC_G)
    print('AUC for GPcounts with Poisson likelihood',AUC_P)
# Out:
# low_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.9942573577603695
# AUC for GPcounts with Gaussian likelihood 0.8595861552386005
# AUC for GPcounts with Poisson likelihood 0.9999375799756561
# low_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.9568677631784277
# AUC for GPcounts with Gaussian likelihood 0.8805592834181206
# AUC for GPcounts with Poisson likelihood 0.7826846852470272
# high_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.9894753086419753
# AUC for GPcounts with Gaussian likelihood 0.8758641975308642
# AUC for GPcounts with Poisson likelihood 0.9978703703703704
# high_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.9129320987654321
# AUC for GPcounts with Gaussian likelihood 0.7864814814814813
# AUC for GPcounts with Poisson likelihood 0.9125

# %%
filesname = ['low_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv'
            ,'low_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv'                                     
            ,'high_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv'
            ,'high_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv']
            
for file in filesname:
    print(file)
    
    Gaussian = pd.read_csv('variance_ratio_Gaussian_'+file,index_col=[0])
    NegativeBinomial = pd.read_csv('variance_ratio_Negative_binomial_'+file,index_col=[0])
    Poisson = pd.read_csv('variance_ratio_Poisson_'+file,index_col=[0])
    
    D = NegativeBinomial.shape[0]
    true_label = np.zeros(D)
    
    for j in range(D):
        if j %2 == 0:
            true_label[j] = 1

    labels = pd.DataFrame(true_label, index =NegativeBinomial.index.values, columns =['label'])
    NegativeBinomial = pd.concat([NegativeBinomial,labels],axis = 1)

    fig = plt.figure()
    
    plt.tick_params(labelsize='large', width=2)     
    fpr_NB, tpr_NB, thresholds_NB = metrics.roc_curve( NegativeBinomial['label'],-1*NegativeBinomial['log_likelihood_ratio'])
    AUC_NB=metrics.auc(fpr_NB, tpr_NB)
    plt.plot(fpr_NB, tpr_NB,color='green',label='GPcounts with Negative binomail likelihood {0:.4f}'.format(AUC_NB))
    
    
    fpr_G, tpr_G, thresholds_G = metrics.roc_curve(NegativeBinomial['label'],-1*Gaussian['log_likelihood_ratio'])
    AUC_G=metrics.auc(fpr_G, tpr_G)
    plt.plot(fpr_G, tpr_G, color='darkorange', label='GPcounts with Gaussian likelihood {0:.4f}'.format(AUC_G))
    
    
    fpr_P, tpr_P, thresholds_P = metrics.roc_curve( NegativeBinomial['label'], -1*Poisson['log_likelihood_ratio'])
    AUC_P=metrics.auc(fpr_P, tpr_P)
    plt.plot(fpr_P, tpr_P,color='blue',label='GPcounts with Poisson likelihood {0:.4f}'.format(AUC_P))
    
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    '''
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    
    plt.subplot(1, 2, 2)
    
    precision_NB, recall_NB, thresholds_NB = metrics.precision_recall_curve( NegativeBinomial['label'], NegativeBinomial['log_likelihood_ratio'])
    plt.plot( recall_NB,precision_NB,color='green',label='GPcounts with Negative binomail likelihood')
    
    precision_G, recall_G, thresholds_G = metrics.precision_recall_curve(NegativeBinomial['label'],Gaussian['log_likelihood_ratio'])
    plt.plot(recall_G, precision_G, color='darkorange', label='GPcounts with Gaussian ll')
    
    precision_P, recall_P, thresholds_P = metrics.precision_recall_curve( NegativeBinomial['label'], Poisson['log_likelihood_ratio'])
    plt.plot( recall_P,precision_P,color='blue',label='GPcounts with Poisson ll')
    
    plt.xlabel('recall')
    plt.ylabel('precision')
    '''
    plt.legend(loc='upper center', bbox_to_anchor=(.56, 0.25))
    plt.show()
    
    print('AUC for GPcounts with Negative Binomial likelihood',AUC_NB)
    print('AUC for GPcounts with Gaussian likelihood',AUC_G)
    print('AUC for GPcounts with Poisson likelihood',AUC_P)
# Out:
# low_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.20679754065104086
# AUC for GPcounts with Gaussian likelihood 0.14291064573515183
# AUC for GPcounts with Poisson likelihood 0.9177616179270309
# low_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.43962423145345025
# AUC for GPcounts with Gaussian likelihood 0.16151181298960707
# AUC for GPcounts with Poisson likelihood 0.23513623170313036
# high_counts_low_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.9014197530864198
# AUC for GPcounts with Gaussian likelihood 0.5357716049382716
# AUC for GPcounts with Poisson likelihood 0.29962962962962963
# high_counts_high_dispersion_non_differentially_expressed_genes_DE_non_DE_genes.csv
# AUC for GPcounts with Negative Binomial likelihood 0.8796296296296297
# AUC for GPcounts with Gaussian likelihood 0.4815740740740741
# AUC for GPcounts with Poisson likelihood 0.33077160493827157

# %%
NegativeBinomial
# Out:
#           Dynamic_model_log_likelihood  Constant_model_log_likelihood  \
# gene_1                       20.991229                      40.051616
# gene_2                       43.799565                      43.755215
# gene_3                       24.730044                      45.737075
# gene_4                       93.957899                      49.196589
# gene_5                       58.886440                      73.949349
# ...                                ...                            ...
# gene_356                    165.688237                     106.102966
# gene_357                     96.800321                      74.548419
# gene_358                    178.650052                     101.274594
# gene_359                     74.991634                      73.317018
# gene_360                    132.555045                     101.613330
#
#           log_likelihood_ratio  label
# gene_1              -19.060387    1.0
# gene_2                0.044350    0.0
# gene_3              -21.007031    1.0
# gene_4               44.761311    0.0
# gene_5              -15.062909    1.0
# ...                        ...    ...
# gene_356             59.585271    0.0
# gene_357             22.251902    1.0
# gene_358             77.375458    0.0
# gene_359              1.674617    1.0
# gene_360             30.941715    0.0
#
# [360 rows x 4 columns]

# %%
from scipy import stats

pval = 1 - stats.chi2.cdf(log_likelihood_ratio, df=1)

pval.reshape(-1)[2]
pval = pd.DataFrame(pval)
pval.to_csv('pval_f.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-976d93b5b516> in <module>
#       1 from scipy import stats
#       2
# ----> 3 pval = 1 - stats.chi2.cdf(log_likelihood_ratio, df=1)
#       4
#       5 pval.reshape(-1)[2]
#
# NameError: name 'log_likelihood_ratio' is not defined

# %%
from scipy import interpolate


def qvalue(pv, pi0=None):
'''
Estimates q-values from p-values
This function is modified based on https://github.com/nfusi/qvalue

GitHub - nfusi/qvalue: Converts p-values in q-values, see (Storey and Tibshirani, 2003)
qvalue. Converts p-values in q-values, see (Storey and Tibshirani, 2003) The only function that needs to be called is 'estimate()'. It will accept a numpy array of pvalues and will return a numpy array of qvalues.
github.com

Args
====
pi0: if None, it's estimated as suggested in Storey and Tibshirani, 2003.
'''
assert(pv.min() >= 0 and pv.max() <= 1), "p-values should be between 0 and 1"

original_shape = pv.shape
pv = pv.ravel()  # flattens the array in place, more efficient than flatten()

m = float(len(pv))

# if the number of hypotheses is small, just set pi0 to 1
if len(pv) < 100 and pi0 is None:
    pi0 = 1.0
elif pi0 is not None:
    pi0 = pi0
else:
    # evaluate pi0 for different lambdas
    pi0 = []
    lam = sp.arange(0, 0.90, 0.01)
    counts = sp.array([(pv > i).sum() for i in sp.arange(0, 0.9, 0.01)])
    for l in range(len(lam)):
        pi0.append(counts[l]/(m*(1-lam[l])))

    pi0 = sp.array(pi0)

    # fit natural cubic spline
    tck = interpolate.splrep(lam, pi0, k=3)
    pi0 = interpolate.splev(lam[-1], tck)

    if pi0 > 1:
        pi0 = 1.0

assert(pi0 >= 0 and pi0 <= 1), "pi0 is not between 0 and 1: %f" % pi0

p_ordered = sp.argsort(pv)
pv = pv[p_ordered]
qv = pi0 * m/len(pv) * pv
qv[-1] = min(qv[-1], 1.0)

for i in range(len(pv)-2, -1, -1):
    qv[i] = min(pi0*m*pv[i]/(i+1.0), qv[i+1])

# reorder qvalues
qv_temp = qv.copy()
qv = sp.zeros_like(qv)
qv[p_ordered] = qv_temp

# reshape qvalues
qv = qv.reshape(original_shape)

return qv
___________


pval = pd.read_csv('pval_f.csv', index_col=0)
qvals = []
pval=pval['2']


qvals = qvalue(pval)


count = 0
for i in qvals :
if i < 0.05 :
    count = count + 1
print ("The numbers greater than 0.05 : " + str(count))
