# %% [markdown]
# # Normalise gene expression data and run two samples test

# %% [markdown]
# Nuha BinTayyash, 2020
#
# This notebook shows how to run [DESeq2](https://bioconductor.org/packages/release/bioc/html/DESeq2.html)  R package to normalise fission gene expression data then run GPcounts two samples test.

# %% [markdown]
# ### load [fission dataset](https://bioconductor.org/packages/3.11/data/experiment/html/fission.html) and normalise it using DESeq2

# %%
library("fission")
data("fission")

# %%
counts <- SummarizedExperiment::assay(fission)
col_data <- fission@colData

# %%
library("DESeq2")

# %%
library("DESeq2")
dds <- DESeqDataSetFromMatrix(countData = counts,
                              colData = col_data,
                              design = ~ strain + minute + strain:minute)

# %%
dds <- estimateSizeFactors(dds)
counts_normalized <-counts(dds, normalized=TRUE)

# %%
write.csv(counts_normalized, file = "fission_counts.csv")
write.csv(col_data, file = "fission_col_data.csv")

# %% [markdown]
# Change R kernel to Python kernel

# %%
import numpy as np
import pandas as pd

# %%
Y = pd.read_csv('fission_counts.csv',index_col=[0])
X = pd.read_csv('fission_col_data.csv',index_col=[0])

# %% [markdown]
# Fit the first gene in fission gene expression data using GPcounts -- Two samples test

# %%
from GPcounts import GPcounts
likelihood = 'Negative_binomial' 
gp_counts = GPcounts(X[['minute']],Y.iloc[[0]]) 
log_likelihood_ratio = gp_counts.Two_samples_test(likelihood)
log_likelihood_ratio
# Out:
# 100%|██████████| 1/1 [00:07<00:00,  7.08s/it]
#             model_1_log_likelihood  model_2_log_likelihood  \
# SPAC212.11             -114.967723               -64.84116
#
#             model_3_log_likelihood  log_likelihood_ratio
# SPAC212.11              -50.550819           3392.741458

# %%
from matplotlib import pyplot as plt
import statsmodels.api as sm

def plot(likelihood,xtest,mean,var,count):
         
    plt.ylabel('Gene Expression', fontsize=16)
    plt.xlabel('Times', fontsize=16)

    plt.scatter(X[['minute']].values,Y.loc[[indexes[i]]].values, s=10, color='black', alpha=0.6) #data

    if likelihood == 'Gaussian':
        plt.fill_between(xtest[:,0],
                            mean[:,0] - 2*np.sqrt(var[:,0]),
                            mean[:,0] + 2*np.sqrt(var[:,0]), alpha=0.2)
    else:
        lowess = sm.nonparametric.lowess
        percentile_5 = lowess(np.percentile(var, 5, axis=0),xtest[:,0],frac=1./5, return_sorted=False)
        percentile_95 = lowess(np.percentile(var, 95, axis=0),xtest[:,0],frac=1./5, return_sorted=False)
        plt.fill_between(xtest[:,0],percentile_5,percentile_95,alpha = 0.2)

    plt.plot(xtest, mean, lw=2) 
    if count == 1:
        plt.show()
    
indexes = log_likelihood_ratio.index.values # list of genes to be plotted 
test = 'Two_samples_test' # name of the test
xtest = np.linspace(np.min(X[['minute']].values),np.max(X[['minute']].values),100)[:,None] # points to make prediction
sample = True # sample or/and load model 

for i in range(len(indexes)):
    fig = plt.figure()
    print(indexes[i])
    count = 1
    params = gp_counts.load_and_sample_models(indexes[i],test,xtest,likelihood,sample)
    for mean,var in zip(params['means'],params['vars']):
        mean = np.array(mean)
        var = np.array(var)
        
        if count == 1:
            xtest = np.linspace(np.min(X[['minute']].values),np.max(X[['minute']].values),100)[:,None] # points to make prediction
    
        elif count == 2:
            xtest = np.linspace(np.min(X[['minute']].values),np.max(X[['minute']][0 : int(X[['minute']].shape[0]/2)].values),100)[:,None] # points to make prediction
            
        else:
            xtest = np.linspace(np.min(X[['minute']][0 : int(X[['minute']].shape[0]/2)].values),np.max(X[['minute']].values),100)[:,None] # points to make prediction 
            
        
        plot(likelihood,xtest,mean,var,count)
        count = count + 1
# Out:
# SPAC212.11
