# %% [markdown]
# ## GPcounts with zero-inflated negative binomial likelihood

# %% [markdown]
# Nuha BinTayyash, 2020
#
# This notebook comapre GPcount fit with zero-inflated negative binomial, negative binomial and Gaussian likelihoods on ScRNA-seq gene expression data for highly expressed genes in Islet $\alpha$ cell from [GSE8737 single cell RNA-seq ](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE87375) dataset.

# %%
import pandas as pd
import numpy as np
import gpflow

# %% [markdown]
# Load $\alpha$ dataset and pseudotime information

# %%
Y = pd.read_csv('alpha_counts.csv',index_col=[0])
X = pd.read_csv('alpha_time_points.csv',index_col=[0])

# %% [markdown]
# #### Fit GPcount with zero inflated negative binomial likelihood

# %%
from GPcounts.GPcounts_Module import Fit_GPcounts

# %%
gene_name = ['Fam184b','Pde1a']
gp_counts = Fit_GPcounts(X,Y.loc[gene_name])

# %% [markdown]
# Probabilty of zeros in Fam184b and Pde1a genes

# %%
Y.loc[gene_name][Y.loc[gene_name] == 0].count(axis=1)/len(Y.columns)
# Out:
# Symbol
# Fam184b    0.862805
# Pde1a      0.689024
# dtype: float64

# %%
from matplotlib import pyplot as plt
import statsmodels.api as sm

def plot():
    plt.tick_params(labelsize='large', width=2)     
    #plt.ylabel('Gene Expression', fontsize=16)
    #plt.xlabel('Times', fontsize=16)
    c = 'royalblue'
    
    if model_index == 3:
        c = 'green'
    
    plt.plot(xtest, mean,color= c, lw=2) 
    
    if likelihood == 'Gaussian':
        plt.fill_between(xtest[:,0],
                            mean[:,0] - 1*np.sqrt(var[:,0]),
                            mean[:,0] + 1*np.sqrt(var[:,0]),color=c,alpha=0.2) # one standard deviation
        plt.fill_between(xtest[:,0],
                            mean[:,0] - 2*np.sqrt(var[:,0]),
                            mean[:,0] + 2*np.sqrt(var[:,0]),color=c, alpha=0.1)# two standard deviation
    else:
       
        lowess = sm.nonparametric.lowess    
        # one standard deviation 68%
        percentile_16 = lowess(np.percentile(var, 16, axis=0),xtest[:,0],frac=1./5, return_sorted=False)
        percentile_16 = [(i > 0) * i for i in percentile_16]
        percentile_84 = lowess(np.percentile(var, 84, axis=0),xtest[:,0],frac=1./5, return_sorted=False)
        percentile_84 = [(i > 0) * i for i in percentile_84]
        plt.fill_between(xtest[:,0],percentile_16,percentile_84,color=c,alpha=0.2)
        
        # two standard deviation 95%
        percentile_5 = lowess(np.percentile(var, 5, axis=0),xtest[:,0],frac=1./5, return_sorted=False)
        percentile_5 = [(i > 0) * i for i in percentile_5]
        percentile_95 = lowess(np.percentile(var,95, axis=0),xtest[:,0],frac=1./5, return_sorted=False)
        percentile_95 = [(i > 0) * i for i in percentile_95]
        plt.fill_between(xtest[:,0],percentile_5,percentile_95,color=c,alpha=0.1)
    
    if test == 'Two_samples_test' and model_index == 1:
        plt.scatter(model.data[0][0:int(model.data[0].shape[0]/2)],model.data[1][0:int(model.data[0].shape[0]/2)], s=30, marker='o', color= 'royalblue',alpha=1.) #data    
        plt.scatter(model.data[0][int(model.data[0].shape[0]/2)::],model.data[1][int(model.data[0].shape[0]/2)::], s=30, marker='o', color= 'green',alpha=1.) #data

    else: 
        plt.scatter(model.data[0],model.data[1],s=30,marker = 'o',color=c,alpha=1.)
    
    
    if not(test == 'Two_samples_test' and model_index == 2):
        plt.show()

# %%
likelihood = 'Zero_inflated_negative_binomial' 
results = gp_counts.Infer_trajectory(likelihood)
results['likelihood']
# Out:
# 100%|██████████| 2/2 [00:36<00:00, 18.28s/it]
#          Dynamic_model_log_likelihood
# Fam184b                   -295.271091
# Pde1a                     -598.080122

# %%
likelihood = 'Zero_inflated_negative_binomial' 
indexes = results['likelihood'].index.values.tolist() # list of genes to be plotted 
test = 'Infer_trajectory' # name of the test
xtest = np.linspace(np.min(X.values)-.1,np.max(X.values)+.1,100)[:,None]

params = gp_counts.load_models(indexes,test,xtest,likelihood)

for i in range(len(indexes)):
    fig = plt.figure()
    print(indexes[i])
    model_index = 1
    for model,mean,var in zip(params['models'][i],params['means'][i],params['vars'][i]):
        plot()
        model_index = model_index + 1
        gpflow.utilities.print_summary(model, fmt='notebook')
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
# Fam184b
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>4.090992018372122                                   </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.18533524194606424                                 </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.31694788937825374                                 </td></tr>
# <tr><td>VGP.likelihood.km      </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>82.21350336001365                                   </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(328, 1)     </td><td>float64</td><td>[[8.95893311e-02...                                 </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 328, 328)</td><td>float64</td><td>[[[5.00654738e-01, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>
# Pde1a
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform     </th><th>prior  </th><th>trainable  </th><th>shape        </th><th>dtype  </th><th>value                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>VGP.kernel.variance    </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>6.312256858901961                                   </td></tr>
# <tr><td>VGP.kernel.lengthscales</td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.9450167834258387                                  </td></tr>
# <tr><td>VGP.likelihood.alpha   </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>0.840480662106685                                   </td></tr>
# <tr><td>VGP.likelihood.km      </td><td>Parameter</td><td>Softplus      </td><td>       </td><td>True       </td><td>()           </td><td>float64</td><td>31.04565664145399                                   </td></tr>
# <tr><td>VGP.q_mu               </td><td>Parameter</td><td>              </td><td>       </td><td>True       </td><td>(328, 1)     </td><td>float64</td><td>[[1.38171334e+00...                                 </td></tr>
# <tr><td>VGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular</td><td>       </td><td>True       </td><td>(1, 328, 328)</td><td>float64</td><td>[[[9.18728451e-02, 0.00000000e+00, 0.00000000e+00...</td></tr>
# </tbody>
# </table>

# %% [markdown]
# #### Fit GPcount with negative binomial likelihood

# %%
likelihood = 'Negative_binomial' 
results= gp_counts.Infer_trajectory(likelihood)
results['likelihood']
# Out:
# 100%|██████████| 2/2 [00:06<00:00,  3.42s/it]
#          Dynamic_model_log_likelihood
# Fam184b                   -316.895257
# Pde1a                     -642.953426

# %%
likelihood = 'Negative_binomial'
params = gp_counts.load_models(indexes,test,xtest,likelihood)
for i in range(len(indexes)):
    fig = plt.figure()
    print(indexes[i])
    model_index = 1
    for model,mean,var in zip(params['models'][i],params['means'][i],params['vars'][i]):
        plot()
        model_index = model_index + 1
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.65it/s]
# Fam184b
# Pde1a

# %% [markdown]
# #### Fit GPcount with Gaussian likelihood

# %%
likelihood = 'Gaussian'
results = gp_counts.Infer_trajectory(likelihood)
results['likelihood']
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.81it/s]
#          Dynamic_model_log_likelihood
# Fam184b                   -442.090622
# Pde1a                     -537.039584

# %%
params = gp_counts.load_models(indexes,test,xtest,likelihood)

for i in range(len(indexes)):
    fig = plt.figure()
    print(indexes[i])
    model_index = 1
    for model,mean,var in zip(params['models'][i],params['means'][i],params['vars'][i]):
        plot()
        model_index = model_index + 1
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 46.32it/s]
# Fam184b
# Pde1a
